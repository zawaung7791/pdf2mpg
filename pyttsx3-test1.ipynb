# %%
import os, pyttsx3, PyPDF2

# %%
# function 1: Extract text from PDF
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        text = ""
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text += page.extract_text()
        return text

# function 2: Convert text to speech and save as MP3
def text_to_speech(text, output_path):
    speaker = pyttsx3.init()
    speaker.setProperty(name='rate', value=200)
    speaker.save_to_file(text, output_path)
    speaker.runAndWait()


# Main function
def convert(pdf_path, output_path):
    print("Extracting text")
    text = extract_text_from_pdf(pdf_path)
    print("Converting speech to MP3")
    text_to_speech(text, output_path)
    print(f"Conversion complete. MP3 saved at '{output_path}'")

# %%
if __name__ == "__main__":
    pdf_path = "./files/onedrive.pdf"  # Provide the path to the input PDF file
    output_path = "./outputs/pyttsx3-onedrive.mp3"  # Provide the desired path for the output MP3 file
    
    convert(pdf_path, output_path)
# Out:
# Extracting text
# Converting speech to MP3
# Conversion complete. MP3 saved at './outputs/pyttsx3-onedrive.mp3'
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# ...
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 153, in _onSynth
#     self._proxy.notify('started-word',
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
# Exception ignored on calling ctypes callback function: <bound method EspeakDriver._onSynth of <pyttsx3.drivers.espeak.EspeakDriver object at 0x7f5c40104bd0>>
# Traceback (most recent call last):
#   File "/home/zawaung/workspaces/python-workspace/pdf2mpg/.venv/lib/python3.11/site-packages/pyttsx3/drivers/espeak.py", line 171, in _onSynth
#     self._proxy.notify('finished-utterance', completed=True)
#     ^^^^^^^^^^^^^^^^^^
# ReferenceError: weakly-referenced object no longer exists
